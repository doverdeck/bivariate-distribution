# %%
#scatter plot info from: https://jakevdp.github.io/PythonDataScienceHandbook/04.02-simple-scatter-plots.html
import pandas as pd
import numpy as np
import math
import matplotlib
#went to https://sda.berkeley.edu/sdaweb/analysis/?dataset=scfcomb then selected income and foodhome as variables and created a CSV file 
df=(pd.read_csv('sub-data.txt'))
#UPDATE this cell with your data source + Dictionary/Codebook
#data source: https://www.census.gov/data/datasets/time-series/demo/cps/cps-asec.2021.html
#data dictionary: https://www2.census.gov/programs-surveys/cps/datasets/2021/march/asec2021_ddl_pub_full.pdf
#import necessary libaries
print(df)
#name file path (you will have download your own dataset and populate the path and choose the appropriate cell to execute) # <-- edit this value! 
#you will run just ONE of the next four code blocks, depending on the file type of your dataset
#read data from CSV (.csv) & print head
#read data from SAS (.sas7bdat or .sas) & print head
#read data from excel (.xls or .xlsx) & print head
#read data from Stata (.dta) & print head
#list columns in data frame
#output frequency table of chosen column in dataset
#prints updated frequency table
#limit dataset to the 113th congress (2013 congress)
print(df.head())
x=df['INCOME']
y=df['FOODHOME']
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
df.plot(kind = 'scatter', title='Food expenditure in relation to increasing household income', ylabel = 'Food expenditure by household', xlabel = 'Household income', figsize=(20, 5), y='FOODHOME', x='INCOME')
#add trendline to plot
# Out:
#           INCOME  FOODHOME
# 0        9737.17       0.0
# 1        9737.17       0.0
# 2        9737.17       0.0
# 3        9737.17       0.0
# 4        9737.17       0.0
# ...          ...       ...
# 238875  21265.36    6000.0
# 238876  21265.36    6000.0
# 238877  21265.36    6000.0
# 238878  21265.36    6000.0
# 238879  20252.73    6000.0
#
# [238880 rows x 2 columns]
#     INCOME  FOODHOME
# 0  9737.17       0.0
# 1  9737.17       0.0
# 2  9737.17       0.0
# 3  9737.17       0.0
# 4  9737.17       0.0
# <AxesSubplot:title={'center':'Food expenditure in relation to increasing household income'}, xlabel='Household income', ylabel='Food expenditure by household'>
